# %%
import pandas as pd

# %%
cd feather\ format
# Out:
# [Errno 2] No such file or directory: 'feather format'
# /Users/tavishipriyam/Desktop/sem4/EVs/feather format

# %%
df = pd.read_csv("male_data.csv")
# Out:
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/2968492199.py:1: DtypeWarning: Columns (0,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("male_data.csv")

# %%
len(data)
# Out:
# 223387

# %%
data = df

# %%
data
# Out:
#        Unnamed: 0 attachments     author_id  conversation_id  \
# 0               1         NaN  1.324897e+18     1.498448e+18
# 1               3         NaN  1.497817e+18     1.498448e+18
# 2               4         NaN  1.213556e+18     1.498448e+18
# 3               5         NaN  1.727390e+09     1.498391e+18
# 4               6         NaN  1.378083e+18     1.498448e+18
# ...           ...         ...           ...              ...
# 223382      53248         NaN  1.025679e+18     1.485585e+18
# 223383      53249         NaN  5.199569e+08     1.485585e+18
# 223384      53251         NaN  1.484017e+18     1.485585e+18
# 223385      53252         NaN  5.586152e+07     1.485585e+18
# 223386      53253         NaN  1.446882e+18     1.485585e+18
#
#                        created_at  \
# 0       2022-02-28 23:59:22+00:00
# 1       2022-02-28 23:59:15+00:00
# 2       2022-02-28 23:58:48+00:00
# 3       2022-02-28 23:58:40+00:00
# 4       2022-02-28 23:58:36+00:00
# ...                           ...
# 223382  2022-01-24 12:07:57+00:00
# 223383  2022-01-24 12:07:53+00:00
# 223384  2022-01-24 12:07:46+00:00
# 223385  2022-01-24 12:07:45+00:00
# 223386  2022-01-24 12:07:42+00:00
#
#                                                  entities            id lang  \
# 0       {'annotations': None, 'cashtags': None, 'hasht...  1.498448e+18   en
# 1       {'annotations': array([{'end': 108, 'normalize...  1.498448e+18   en
# 2       {'annotations': array([{'end': 94, 'normalized...  1.498448e+18   en
# 3       {'annotations': array([{'end': 34, 'normalized...  1.498448e+18   en
# 4       {'annotations': array([{'end': 127, 'normalize...  1.498448e+18   en
# ...                                                   ...           ...  ...
# 223382  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223383  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223384  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223385  {'annotations': array([{'end': 31, 'normalized...  1.485585e+18   en
# 223386  {'annotations': array([{'end': 79, 'normalized...  1.485585e+18   en
#
#                                            public_metrics  \
# 0       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 1       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 2       {'like_count': 3, 'quote_count': 0, 'reply_cou...
# 3       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 4       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# ...                                                   ...
# 223382  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223383  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223384  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223385  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223386  {'like_count': 0, 'quote_count': 0, 'reply_cou...
#
#                                                      text  \
# 0       RT @HackRead: On hacked TV transmissions #Anon...
# 1       RT @softwarnet: #infosec \nhttps://t.co/x5meu1...
# 2       A problem for electric vehicle owners? "Anonym...
# 3       @garyblack00 I can’t afford a Tesla right now ...
# 4       RT @kathygpr: Remember: The previous admin was...
# ...                                                   ...
# 223382  RT @LucidMotors: The longest range car of the ...
# 223383  RT @teamswiftparrot: I’m not a car guy, but at...
# 223384  Break-Through Ultra-Precision Machining Platfo...
# 223385  RT @hartfordcourant: Connecticut is embarking ...
# 223386  RT @richjaguarz: To celebrate the announcement...
#
#                                                      user  \
# 0       {'created_at': '2020-11-07T02:10:57.000Z', 'de...
# 1       {'created_at': '2022-02-27T06:12:17.000Z', 'de...
# 2       {'created_at': '2020-01-04T20:22:27.000Z', 'de...
# 3       {'created_at': '2013-09-04T03:01:38.000Z', 'de...
# 4       {'created_at': '2021-04-02T20:33:02.000Z', 'de...
# ...                                                   ...
# 223382  {'created_at': '2018-08-04T09:43:28.000Z', 'de...
# 223383  {'created_at': '2012-03-10T00:38:28.000Z', 'de...
# 223384  {'created_at': '2022-01-20T04:17:10.000Z', 'de...
# 223385  {'created_at': '2009-07-11T16:04:56.000Z', 'de...
# 223386  {'created_at': '2021-10-09T16:53:52.000Z', 'de...
#
#                                         referenced_tweets  \
# 0       [{'id': '1498381160380080135', 'type': 'retwee...
# 1       [{'id': '1498342666546733056', 'type': 'retwee...
# 2                                                     NaN
# 3       [{'id': '1498391412659953673', 'type': 'replie...
# 4       [{'id': '1498446693502623745', 'type': 'retwee...
# ...                                                   ...
# 223382  [{'id': '1460217211100954624', 'type': 'retwee...
# 223383  [{'id': '1485520486369214464', 'type': 'retwee...
# 223384                                                NaN
# 223385  [{'id': '1485583832120180746', 'type': 'retwee...
# 223386  [{'id': '1484194465451769858', 'type': 'retwee...
#
#                                          retweeted_status  \
# 0       {'attachments': None, 'author_id': '411396541'...
# 1       {'attachments': None, 'author_id': '4148621113...
# 2                                                     NaN
# 3       {'attachments': {'media_keys': array(['3_14983...
# 4       {'attachments': None, 'author_id': '8204921770...
# ...                                                   ...
# 223382  {'attachments': {'media_keys': array(['13_1460...
# 223383  {'attachments': None, 'author_id': '2872961599...
# 223384                                                NaN
# 223385  {'attachments': None, 'author_id': '14708814',...
# 223386  {'attachments': {'media_keys': array(['3_14841...
#
#         in_reply_to_user_id  geo withheld  context_annotations gender    age
# 0                       NaN  NaN      NaN                  NaN   male   <=18
# 1                       NaN  NaN      NaN                  NaN   male   >=40
# 2                       NaN  NaN      NaN                  NaN   male   >=40
# 3              1.161704e+18  NaN      NaN                  NaN   male   >=40
# 4                       NaN  NaN      NaN                  NaN   male   >=40
# ...                     ...  ...      ...                  ...    ...    ...
# 223382                  NaN  NaN      NaN                  NaN   male  30-39
# 223383                  NaN  NaN      NaN                  NaN   male   <=18
# 223384                  NaN  NaN      NaN                  NaN   male   >=40
# 223385                  NaN  NaN      NaN                  NaN   male  30-39
# 223386                  NaN  NaN      NaN                  NaN   male  30-39
#
# [223387 rows x 19 columns]

# %%
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['http','https','zpxvxdlj','co','rt','ev','evs','electric','car','vehicle','from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
# !pip3 install -U spacy
# Out:
# Requirement already satisfied: spacy in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: setuptools in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (58.2.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (8.1.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (1.21.4)
# Requirement already satisfied: pathy>=0.3.5 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (0.6.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: jinja2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from jinja2->spacy) (2.1.1)
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 9.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: packaging>=20.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: pathy>=0.3.5 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: setuptools in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (58.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.62.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: jinja2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.26.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.9.24)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
data
# Out:
#        Unnamed: 0 attachments     author_id  conversation_id  \
# 0               1         NaN  1.324897e+18     1.498448e+18
# 1               3         NaN  1.497817e+18     1.498448e+18
# 2               4         NaN  1.213556e+18     1.498448e+18
# 3               5         NaN  1.727390e+09     1.498391e+18
# 4               6         NaN  1.378083e+18     1.498448e+18
# ...           ...         ...           ...              ...
# 223382      53248         NaN  1.025679e+18     1.485585e+18
# 223383      53249         NaN  5.199569e+08     1.485585e+18
# 223384      53251         NaN  1.484017e+18     1.485585e+18
# 223385      53252         NaN  5.586152e+07     1.485585e+18
# 223386      53253         NaN  1.446882e+18     1.485585e+18
#
#                        created_at  \
# 0       2022-02-28 23:59:22+00:00
# 1       2022-02-28 23:59:15+00:00
# 2       2022-02-28 23:58:48+00:00
# 3       2022-02-28 23:58:40+00:00
# 4       2022-02-28 23:58:36+00:00
# ...                           ...
# 223382  2022-01-24 12:07:57+00:00
# 223383  2022-01-24 12:07:53+00:00
# 223384  2022-01-24 12:07:46+00:00
# 223385  2022-01-24 12:07:45+00:00
# 223386  2022-01-24 12:07:42+00:00
#
#                                                  entities            id lang  \
# 0       {'annotations': None, 'cashtags': None, 'hasht...  1.498448e+18   en
# 1       {'annotations': array([{'end': 108, 'normalize...  1.498448e+18   en
# 2       {'annotations': array([{'end': 94, 'normalized...  1.498448e+18   en
# 3       {'annotations': array([{'end': 34, 'normalized...  1.498448e+18   en
# 4       {'annotations': array([{'end': 127, 'normalize...  1.498448e+18   en
# ...                                                   ...           ...  ...
# 223382  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223383  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223384  {'annotations': None, 'cashtags': None, 'hasht...  1.485585e+18   en
# 223385  {'annotations': array([{'end': 31, 'normalized...  1.485585e+18   en
# 223386  {'annotations': array([{'end': 79, 'normalized...  1.485585e+18   en
#
#                                            public_metrics  \
# 0       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 1       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 2       {'like_count': 3, 'quote_count': 0, 'reply_cou...
# 3       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 4       {'like_count': 0, 'quote_count': 0, 'reply_cou...
# ...                                                   ...
# 223382  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223383  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223384  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223385  {'like_count': 0, 'quote_count': 0, 'reply_cou...
# 223386  {'like_count': 0, 'quote_count': 0, 'reply_cou...
#
#                                                      text  \
# 0       RT @HackRead: On hacked TV transmissions #Anon...
# 1       RT @softwarnet: #infosec \nhttps://t.co/x5meu1...
# 2       A problem for electric vehicle owners? "Anonym...
# 3       @garyblack00 I can’t afford a Tesla right now ...
# 4       RT @kathygpr: Remember: The previous admin was...
# ...                                                   ...
# 223382  RT @LucidMotors: The longest range car of the ...
# 223383  RT @teamswiftparrot: I’m not a car guy, but at...
# 223384  Break-Through Ultra-Precision Machining Platfo...
# 223385  RT @hartfordcourant: Connecticut is embarking ...
# 223386  RT @richjaguarz: To celebrate the announcement...
#
#                                                      user  \
# 0       {'created_at': '2020-11-07T02:10:57.000Z', 'de...
# 1       {'created_at': '2022-02-27T06:12:17.000Z', 'de...
# 2       {'created_at': '2020-01-04T20:22:27.000Z', 'de...
# 3       {'created_at': '2013-09-04T03:01:38.000Z', 'de...
# 4       {'created_at': '2021-04-02T20:33:02.000Z', 'de...
# ...                                                   ...
# 223382  {'created_at': '2018-08-04T09:43:28.000Z', 'de...
# 223383  {'created_at': '2012-03-10T00:38:28.000Z', 'de...
# 223384  {'created_at': '2022-01-20T04:17:10.000Z', 'de...
# 223385  {'created_at': '2009-07-11T16:04:56.000Z', 'de...
# 223386  {'created_at': '2021-10-09T16:53:52.000Z', 'de...
#
#                                         referenced_tweets  \
# 0       [{'id': '1498381160380080135', 'type': 'retwee...
# 1       [{'id': '1498342666546733056', 'type': 'retwee...
# 2                                                     NaN
# 3       [{'id': '1498391412659953673', 'type': 'replie...
# 4       [{'id': '1498446693502623745', 'type': 'retwee...
# ...                                                   ...
# 223382  [{'id': '1460217211100954624', 'type': 'retwee...
# 223383  [{'id': '1485520486369214464', 'type': 'retwee...
# 223384                                                NaN
# 223385  [{'id': '1485583832120180746', 'type': 'retwee...
# 223386  [{'id': '1484194465451769858', 'type': 'retwee...
#
#                                          retweeted_status  \
# 0       {'attachments': None, 'author_id': '411396541'...
# 1       {'attachments': None, 'author_id': '4148621113...
# 2                                                     NaN
# 3       {'attachments': {'media_keys': array(['3_14983...
# 4       {'attachments': None, 'author_id': '8204921770...
# ...                                                   ...
# 223382  {'attachments': {'media_keys': array(['13_1460...
# 223383  {'attachments': None, 'author_id': '2872961599...
# 223384                                                NaN
# 223385  {'attachments': None, 'author_id': '14708814',...
# 223386  {'attachments': {'media_keys': array(['3_14841...
#
#         in_reply_to_user_id  geo withheld  context_annotations gender    age
# 0                       NaN  NaN      NaN                  NaN   male   <=18
# 1                       NaN  NaN      NaN                  NaN   male   >=40
# 2                       NaN  NaN      NaN                  NaN   male   >=40
# 3              1.161704e+18  NaN      NaN                  NaN   male   >=40
# 4                       NaN  NaN      NaN                  NaN   male   >=40
# ...                     ...  ...      ...                  ...    ...    ...
# 223382                  NaN  NaN      NaN                  NaN   male  30-39
# 223383                  NaN  NaN      NaN                  NaN   male   <=18
# 223384                  NaN  NaN      NaN                  NaN   male   >=40
# 223385                  NaN  NaN      NaN                  NaN   male  30-39
# 223386                  NaN  NaN      NaN                  NaN   male  30-39
#
# [223387 rows x 19 columns]

# %%
for i in range(len(dataa)):
    if type(dataa[i])!= str:
        print(i)
# Out:
# 52157
# 52158

# %%
dataa[52158]
# Out:
# nan

# %%
dataa.

# %%
def sent_to_words(sentences):
    for sent in sentences:
        if type(sent)!= str:
            continue
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
dataa = data.text.values.tolist()
data_words = list(sent_to_words(dataa))
print(data_words[:1])
# Out:
# [['rt', 'on', 'hacked', 'tv', 'transmissions', 'anonymous', 'displayed', 'the', 'national', 'anthem', 'of', 'ukraine', 'while', 'another', 'video', 'shows', 'an', 'electric', 'vehicl']]

# %%
type(dataa[0])
# Out:
# str

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# !python3 -m spacy download en  # run in terminal once
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.042*"charge" + 0.041*"battery" + 0.028*"station" + 0.026*"pace" + '
#   '0.024*"holder" + 0.024*"giveaway" + 0.023*"giving_away" + 0.021*"celebrate" '
#   '+ 0.017*"amp" + 0.012*"drive"'),
#  (1,
#   '0.046*"buy" + 0.030*"road" + 0.030*"people" + 0.019*"still" + 0.017*"old" + '
#   '0.016*"find" + 0.013*"never" + 0.012*"start_collecte" + 0.012*"race" + '
#   '0.011*"boom"'),
#  (2,
#   '0.041*"truck" + 0.029*"tesla" + 0.019*"demand" + 0.018*"sale" + '
#   '0.017*"production" + 0.016*"hybrid" + 0.015*"market" + 0.014*"change" + '
#   '0.013*"state" + 0.013*"mobility"'),
#  (3,
#   '0.073*"first" + 0.068*"new" + 0.062*"announcement" + 0.044*"shodlurhj" + '
#   '0.034*"year" + 0.028*"next" + 0.020*"future" + 0.017*"invest" + '
#   '0.017*"company" + 0.017*"launch"')]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/181664221.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/181664221.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               1              0.4178
# 1            1               0              0.6343
# 2            2               0              0.6242
# 3            3               0              0.5251
# 4            4               3              0.7660
# 5            5               0              0.6697
# 6            6               0              0.6947
# 7            7               2              0.5685
# 8            8               1              0.4178
# 9            9               0              0.5766
#
#                                             Keywords  \
# 0  buy, road, people, still, old, find, never, st...
# 1  charge, battery, station, pace, holder, giveaw...
# 2  charge, battery, station, pace, holder, giveaw...
# 3  charge, battery, station, pace, holder, giveaw...
# 4  first, new, announcement, shodlurhj, year, nex...
# 5  charge, battery, station, pace, holder, giveaw...
# 6  charge, battery, station, pace, holder, giveaw...
# 7  truck, tesla, demand, sale, production, hybrid...
# 8  buy, road, people, still, old, find, never, st...
# 9  charge, battery, station, pace, holder, giveaw...
#
#                                                 Text
# 0                                  [display, vehicl]
# 1                                [charger, dickhead]
# 2  [problem, owner, anonymous, disabled, charge, ...
# 3  [afford, pretty, much, swear, ever, buy, compa...
# 4                  [remember, previous_admin, today]
# 5  [basic, drivetrain, bev, offer, advantage, pot...
# 6  [idea, halt, huge, battery, manufacture, minin...
# 7  [energy, sale, rocket, last, year, growth, sal...
# 8                                  [display, vehicl]
# 9  [plan, downtown, free, city, develop, short, t...

# %%
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0          0              0.9690
# 1          1              0.9285
# 2          2              0.9458
# 3          3              0.9344
#
#                                                                                Keywords  \
# 0  charge, battery, station, pace, holder, giveaway, giving_away, celebrate, amp, drive
# 1                buy, road, people, still, old, find, never, start_collecte, race, boom
# 2       truck, tesla, demand, sale, production, hybrid, market, change, state, mobility
# 3      first, new, announcement, shodlurhj, year, next, future, invest, company, launch
#
#                                                                                    Representative Text
# 0  [charge, speed, issue, low, soon, anyway, swap, moot, amp, already, enough, raw_material, availa...
# 1          [toy, alloy, rc_buggy, mini, boy, scale, shock, absorption, gift, boy, teenager, fzjcqaqte]
# 2  [sale, unit, nearly, half, total, sale, global, accord, global, analyst, total, sell, worldwide,...
# 3  [build, build, first, crewe_plant, cheshire, part, investment, programme, full, story, ukmfg, ar...

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 1000, color='navy')
plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 1000), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,1000,9))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
import seaborn as sns
import matplotlib.colors as mcolors
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

fig, axes = plt.subplots(2,2,figsize=(16,14), dpi=160, sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):    
    df_dominant_topic_sub = df_dominant_topic.loc[df_dominant_topic.Dominant_Topic == i, :]
    doc_lens = [len(d) for d in df_dominant_topic_sub.Text]
    ax.hist(doc_lens, bins = 1000, color=cols[i])
    ax.tick_params(axis='y', labelcolor=cols[i], color=cols[i])
    sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
    ax.set(xlim=(0, 1000), xlabel='Document Word Count')
    ax.set_ylabel('Number of Documents', color=cols[i])
    ax.set_title('Topic: '+str(i), fontdict=dict(size=16, color=cols[i]))

fig.tight_layout()
fig.subplots_adjust(top=0.90)
plt.xticks(np.linspace(0,1000,9))
fig.suptitle('Distribution of Document Word Counts by Dominant Topic', fontsize=22)
plt.show()
# Out:
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/2460086901.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/2460086901.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/2460086901.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/2460086901.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

# %%
out
# Out:
# [['charge', 0, 0.041782122, 50203],
#  ['battery', 0, 0.0410373, 15697],
#  ['station', 0, 0.02792303, 21521],
#  ['pace', 0, 0.026075352, 592],
#  ['holder', 0, 0.02377295, 477],
#  ['giveaway', 0, 0.023583958, 206],
#  ['giving_away', 0, 0.02330463, 153],
#  ['celebrate', 0, 0.020914778, 265],
#  ['amp', 0, 0.016667398, 8879],
#  ['drive', 0, 0.012270812, 8949],
#  ['buy', 1, 0.04613701, 14935],
#  ['road', 1, 0.030179327, 2855],
#  ['people', 1, 0.029980257, 6266],
#  ['still', 1, 0.018930137, 3371],
#  ['old', 1, 0.016607136, 1790],
#  ['find', 1, 0.015551107, 2782],
#  ['never', 1, 0.013027195, 2004],
#  ['start_collecte', 1, 0.012326042, 148],
#  ['race', 1, 0.012220818, 3742],
#  ['boom', 1, 0.011147865, 889],
#  ['truck', 2, 0.040666834, 10285],
#  ['tesla', 2, 0.029153278, 19375],
#  ['demand', 2, 0.018506797, 1593],
#  ['sale', 2, 0.018497506, 6491],
#  ['production', 2, 0.017353332, 2402],
#  ['hybrid', 2, 0.016241003, 6643],
#  ['market', 2, 0.015145322, 5228],
#  ['change', 2, 0.013748133, 4516],
#  ['state', 2, 0.013441713, 5416],
#  ['mobility', 2, 0.0126480805, 872],
#  ['first', 3, 0.07263986, 11132],
#  ['new', 3, 0.06827272, 18910],
#  ['announcement', 3, 0.062489588, 514],
#  ['shodlurhj', 3, 0.043858316, 380],
#  ['year', 3, 0.034124494, 11230],
#  ['next', 3, 0.028132629, 2965],
#  ['future', 3, 0.019786479, 5966],
#  ['invest', 3, 0.01726617, 3570],
#  ['company', 3, 0.017181428, 12690],
#  ['launch', 3, 0.017017549, 2399],
#  ['charge', 0, 0.041782122, 50203],
#  ['battery', 0, 0.0410373, 15697],
#  ['station', 0, 0.02792303, 21521],
#  ['pace', 0, 0.026075352, 592],
#  ['holder', 0, 0.02377295, 477],
#  ['giveaway', 0, 0.023583958, 206],
#  ['giving_away', 0, 0.02330463, 153],
#  ['celebrate', 0, 0.020914778, 265],
#  ['amp', 0, 0.016667398, 8879],
#  ['drive', 0, 0.012270812, 8949],
#  ['buy', 1, 0.04613701, 14935],
#  ['road', 1, 0.030179327, 2855],
#  ['people', 1, 0.029980257, 6266],
#  ['still', 1, 0.018930137, 3371],
#  ['old', 1, 0.016607136, 1790],
#  ['find', 1, 0.015551107, 2782],
#  ['never', 1, 0.013027195, 2004],
#  ['start_collecte', 1, 0.012326042, 148],
#  ['race', 1, 0.012220818, 3742],
#  ['boom', 1, 0.011147865, 889],
#  ['truck', 2, 0.040666834, 10285],
#  ['tesla', 2, 0.029153278, 19375],
#  ['demand', 2, 0.018506797, 1593],
#  ['sale', 2, 0.018497506, 6491],
#  ['production', 2, 0.017353332, 2402],
#  ['hybrid', 2, 0.016241003, 6643],
#  ['market', 2, 0.015145322, 5228],
#  ['change', 2, 0.013748133, 4516],
#  ['state', 2, 0.013441713, 5416],
#  ['mobility', 2, 0.0126480805, 872],
#  ['first', 3, 0.07263986, 11132],
#  ['new', 3, 0.06827272, 18910],
#  ['announcement', 3, 0.062489588, 514],
#  ['shodlurhj', 3, 0.043858316, 380],
#  ['year', 3, 0.034124494, 11230],
#  ['next', 3, 0.028132629, 2965],
#  ['future', 3, 0.019786479, 5966],
#  ['invest', 3, 0.01726617, 3570],
#  ['company', 3, 0.017181428, 12690],
#  ['launch', 3, 0.017017549, 2399]]

# %%
df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        
df.head()
# Out:
#       word  topic_id  importance  word_count
# 0   charge         0    0.041782       50203
# 1  battery         0    0.041037       15697
# 2  station         0    0.027923       21521
# 3     pace         0    0.026075         592
# 4   holder         0    0.023773         477

# %%
df.to_csv("male_topics.csv")

# %%
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
#     ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()
# Out:
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/3335660495.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/3335660495.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/3335660495.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# /var/folders/23/nlj2ws3n7mz6my6588wvrlsw0000gn/T/ipykernel_94527/3335660495.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')

# %%
from matplotlib.patches import Rectangle

def sentences_chart(lda_model=lda_model, corpus=corpus, start = 0, end = 13):
    corp = corpus[start:end]
    mycolors = [color for name, color in mcolors.TABLEAU_COLORS.items()]

    fig, axes = plt.subplots(end-start, 1, figsize=(20, (end-start)*0.95), dpi=160)       
    axes[0].axis('off')
    for i, ax in enumerate(axes):
        if i > 0:
            corp_cur = corp[i-1] 
            topic_percs, wordid_topics, wordid_phivalues = lda_model[corp_cur]
            word_dominanttopic = [(lda_model.id2word[wd], topic[0]) for wd, topic in wordid_topics]    
            ax.text(0.01, 0.5, "Doc " + str(i-1) + ": ", verticalalignment='center',
                    fontsize=16, color='black', transform=ax.transAxes, fontweight=700)

            # Draw Rectange
            topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
            ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1, 
                                   color=mycolors[topic_percs_sorted[0][0]], linewidth=2))

            word_pos = 0.06
            for j, (word, topics) in enumerate(word_dominanttopic):
                if j < 14:
                    ax.text(word_pos, 0.5, word,
                            horizontalalignment='left',
                            verticalalignment='center',
                            fontsize=16, color=mycolors[topics],
                            transform=ax.transAxes, fontweight=700)
                    word_pos += .009 * len(word)  # to move the word for the next iter
                    ax.axis('off')
            ax.text(word_pos, 0.5, '. . .',
                    horizontalalignment='left',
                    verticalalignment='center',
                    fontsize=16, color='black',
                    transform=ax.transAxes)       

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.suptitle('Sentence Topic Coloring for Documents: ' + str(start) + ' to ' + str(end-2), fontsize=22, y=0.95, fontweight=700)
    plt.tight_layout()
    plt.show()

# %%
sentences_chart()

# %%
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
from matplotlib.ticker import FuncFormatter
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
# ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()

# %%
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 4
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)
# Out:
# /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 211950 samples in 0.045s...
# [t-SNE] Computed neighbors for 211950 samples in 3.769s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 211950
# [t-SNE] Computed conditional probabilities for sample 2000 / 211950
# [t-SNE] Computed conditional probabilities for sample 3000 / 211950
# [t-SNE] Computed conditional probabilities for sample 4000 / 211950
# [t-SNE] Computed conditional probabilities for sample 5000 / 211950
# [t-SNE] Computed conditional probabilities for sample 6000 / 211950
# [t-SNE] Computed conditional probabilities for sample 7000 / 211950
# [t-SNE] Computed conditional probabilities for sample 8000 / 211950
# [t-SNE] Computed conditional probabilities for sample 9000 / 211950
# [t-SNE] Computed conditional probabilities for sample 10000 / 211950
# [t-SNE] Computed conditional probabilities for sample 11000 / 211950
# [t-SNE] Computed conditional probabilities for sample 12000 / 211950
# [t-SNE] Computed conditional probabilities for sample 13000 / 211950
# [t-SNE] Computed conditional probabilities for sample 14000 / 211950
# [t-SNE] Computed conditional probabilities for sample 15000 / 211950
# [t-SNE] Computed conditional probabilities for sample 16000 / 211950
# [t-SNE] Computed conditional probabilities for sample 17000 / 211950
# [t-SNE] Computed conditional probabilities for sample 18000 / 211950
# [t-SNE] Computed conditional probabilities for sample 19000 / 211950
# [t-SNE] Computed conditional probabilities for sample 20000 / 211950
# [t-SNE] Computed conditional probabilities for sample 21000 / 211950
# [t-SNE] Computed conditional probabilities for sample 22000 / 211950
# [t-SNE] Computed conditional probabilities for sample 23000 / 211950
# [t-SNE] Computed conditional probabilities for sample 24000 / 211950
# [t-SNE] Computed conditional probabilities for sample 25000 / 211950
# [t-SNE] Computed conditional probabilities for sample 26000 / 211950
# [t-SNE] Computed conditional probabilities for sample 27000 / 211950
# [t-SNE] Computed conditional probabilities for sample 28000 / 211950
# [t-SNE] Computed conditional probabilities for sample 29000 / 211950
# [t-SNE] Computed conditional probabilities for sample 30000 / 211950
# [t-SNE] Computed conditional probabilities for sample 31000 / 211950
# [t-SNE] Computed conditional probabilities for sample 32000 / 211950
# [t-SNE] Computed conditional probabilities for sample 33000 / 211950
# [t-SNE] Computed conditional probabilities for sample 34000 / 211950
# [t-SNE] Computed conditional probabilities for sample 35000 / 211950
# [t-SNE] Computed conditional probabilities for sample 36000 / 211950
# [t-SNE] Computed conditional probabilities for sample 37000 / 211950
# [t-SNE] Computed conditional probabilities for sample 38000 / 211950
# [t-SNE] Computed conditional probabilities for sample 39000 / 211950
# [t-SNE] Computed conditional probabilities for sample 40000 / 211950
# [t-SNE] Computed conditional probabilities for sample 41000 / 211950
# [t-SNE] Computed conditional probabilities for sample 42000 / 211950
# [t-SNE] Computed conditional probabilities for sample 43000 / 211950
# [t-SNE] Computed conditional probabilities for sample 44000 / 211950
# [t-SNE] Computed conditional probabilities for sample 45000 / 211950
# [t-SNE] Computed conditional probabilities for sample 46000 / 211950
# [t-SNE] Computed conditional probabilities for sample 47000 / 211950
# [t-SNE] Computed conditional probabilities for sample 48000 / 211950
# [t-SNE] Computed conditional probabilities for sample 49000 / 211950
# [t-SNE] Computed conditional probabilities for sample 50000 / 211950
# [t-SNE] Computed conditional probabilities for sample 51000 / 211950
# [t-SNE] Computed conditional probabilities for sample 52000 / 211950
# [t-SNE] Computed conditional probabilities for sample 53000 / 211950
# [t-SNE] Computed conditional probabilities for sample 54000 / 211950
# [t-SNE] Computed conditional probabilities for sample 55000 / 211950
# [t-SNE] Computed conditional probabilities for sample 56000 / 211950
# [t-SNE] Computed conditional probabilities for sample 57000 / 211950
# [t-SNE] Computed conditional probabilities for sample 58000 / 211950
# [t-SNE] Computed conditional probabilities for sample 59000 / 211950
# [t-SNE] Computed conditional probabilities for sample 60000 / 211950
# [t-SNE] Computed conditional probabilities for sample 61000 / 211950
# [t-SNE] Computed conditional probabilities for sample 62000 / 211950
# [t-SNE] Computed conditional probabilities for sample 63000 / 211950
# [t-SNE] Computed conditional probabilities for sample 64000 / 211950
# [t-SNE] Computed conditional probabilities for sample 65000 / 211950
# [t-SNE] Computed conditional probabilities for sample 66000 / 211950
# [t-SNE] Computed conditional probabilities for sample 67000 / 211950
# [t-SNE] Computed conditional probabilities for sample 68000 / 211950
# [t-SNE] Computed conditional probabilities for sample 69000 / 211950
# [t-SNE] Computed conditional probabilities for sample 70000 / 211950
# [t-SNE] Computed conditional probabilities for sample 71000 / 211950
# [t-SNE] Computed conditional probabilities for sample 72000 / 211950
# [t-SNE] Computed conditional probabilities for sample 73000 / 211950
# [t-SNE] Computed conditional probabilities for sample 74000 / 211950
# [t-SNE] Computed conditional probabilities for sample 75000 / 211950
# [t-SNE] Computed conditional probabilities for sample 76000 / 211950
# [t-SNE] Computed conditional probabilities for sample 77000 / 211950
# [t-SNE] Computed conditional probabilities for sample 78000 / 211950
# [t-SNE] Computed conditional probabilities for sample 79000 / 211950
# [t-SNE] Computed conditional probabilities for sample 80000 / 211950
# [t-SNE] Computed conditional probabilities for sample 81000 / 211950
# [t-SNE] Computed conditional probabilities for sample 82000 / 211950
# [t-SNE] Computed conditional probabilities for sample 83000 / 211950
# [t-SNE] Computed conditional probabilities for sample 84000 / 211950
# [t-SNE] Computed conditional probabilities for sample 85000 / 211950
# [t-SNE] Computed conditional probabilities for sample 86000 / 211950
# [t-SNE] Computed conditional probabilities for sample 87000 / 211950
# [t-SNE] Computed conditional probabilities for sample 88000 / 211950
# [t-SNE] Computed conditional probabilities for sample 89000 / 211950
# [t-SNE] Computed conditional probabilities for sample 90000 / 211950
# [t-SNE] Computed conditional probabilities for sample 91000 / 211950
# [t-SNE] Computed conditional probabilities for sample 92000 / 211950
# [t-SNE] Computed conditional probabilities for sample 93000 / 211950
# [t-SNE] Computed conditional probabilities for sample 94000 / 211950
# [t-SNE] Computed conditional probabilities for sample 95000 / 211950
# [t-SNE] Computed conditional probabilities for sample 96000 / 211950
# [t-SNE] Computed conditional probabilities for sample 97000 / 211950
# [t-SNE] Computed conditional probabilities for sample 98000 / 211950
# [t-SNE] Computed conditional probabilities for sample 99000 / 211950
# [t-SNE] Computed conditional probabilities for sample 100000 / 211950
# [t-SNE] Computed conditional probabilities for sample 101000 / 211950
# [t-SNE] Computed conditional probabilities for sample 102000 / 211950
# [t-SNE] Computed conditional probabilities for sample 103000 / 211950
# [t-SNE] Computed conditional probabilities for sample 104000 / 211950
# [t-SNE] Computed conditional probabilities for sample 105000 / 211950
# [t-SNE] Computed conditional probabilities for sample 106000 / 211950
# [t-SNE] Computed conditional probabilities for sample 107000 / 211950
# [t-SNE] Computed conditional probabilities for sample 108000 / 211950
# [t-SNE] Computed conditional probabilities for sample 109000 / 211950
# [t-SNE] Computed conditional probabilities for sample 110000 / 211950
# [t-SNE] Computed conditional probabilities for sample 111000 / 211950
# [t-SNE] Computed conditional probabilities for sample 112000 / 211950
# [t-SNE] Computed conditional probabilities for sample 113000 / 211950
# [t-SNE] Computed conditional probabilities for sample 114000 / 211950
# [t-SNE] Computed conditional probabilities for sample 115000 / 211950
# [t-SNE] Computed conditional probabilities for sample 116000 / 211950
# [t-SNE] Computed conditional probabilities for sample 117000 / 211950
# [t-SNE] Computed conditional probabilities for sample 118000 / 211950
# [t-SNE] Computed conditional probabilities for sample 119000 / 211950
# [t-SNE] Computed conditional probabilities for sample 120000 / 211950
# [t-SNE] Computed conditional probabilities for sample 121000 / 211950
# [t-SNE] Computed conditional probabilities for sample 122000 / 211950
# [t-SNE] Computed conditional probabilities for sample 123000 / 211950
# [t-SNE] Computed conditional probabilities for sample 124000 / 211950
# [t-SNE] Computed conditional probabilities for sample 125000 / 211950
# [t-SNE] Computed conditional probabilities for sample 126000 / 211950
# [t-SNE] Computed conditional probabilities for sample 127000 / 211950
# [t-SNE] Computed conditional probabilities for sample 128000 / 211950
# [t-SNE] Computed conditional probabilities for sample 129000 / 211950
# [t-SNE] Computed conditional probabilities for sample 130000 / 211950
# [t-SNE] Computed conditional probabilities for sample 131000 / 211950
# [t-SNE] Computed conditional probabilities for sample 132000 / 211950
# [t-SNE] Computed conditional probabilities for sample 133000 / 211950
# [t-SNE] Computed conditional probabilities for sample 134000 / 211950
# [t-SNE] Computed conditional probabilities for sample 135000 / 211950
# [t-SNE] Computed conditional probabilities for sample 136000 / 211950
# [t-SNE] Computed conditional probabilities for sample 137000 / 211950
# [t-SNE] Computed conditional probabilities for sample 138000 / 211950
# [t-SNE] Computed conditional probabilities for sample 139000 / 211950
# [t-SNE] Computed conditional probabilities for sample 140000 / 211950
# [t-SNE] Computed conditional probabilities for sample 141000 / 211950
# [t-SNE] Computed conditional probabilities for sample 142000 / 211950
# [t-SNE] Computed conditional probabilities for sample 143000 / 211950
# [t-SNE] Computed conditional probabilities for sample 144000 / 211950
# [t-SNE] Computed conditional probabilities for sample 145000 / 211950
# [t-SNE] Computed conditional probabilities for sample 146000 / 211950
# [t-SNE] Computed conditional probabilities for sample 147000 / 211950
# [t-SNE] Computed conditional probabilities for sample 148000 / 211950
# [t-SNE] Computed conditional probabilities for sample 149000 / 211950
# [t-SNE] Computed conditional probabilities for sample 150000 / 211950
# [t-SNE] Computed conditional probabilities for sample 151000 / 211950
# [t-SNE] Computed conditional probabilities for sample 152000 / 211950
# [t-SNE] Computed conditional probabilities for sample 153000 / 211950
# [t-SNE] Computed conditional probabilities for sample 154000 / 211950
# [t-SNE] Computed conditional probabilities for sample 155000 / 211950
# [t-SNE] Computed conditional probabilities for sample 156000 / 211950
# [t-SNE] Computed conditional probabilities for sample 157000 / 211950
# [t-SNE] Computed conditional probabilities for sample 158000 / 211950
# [t-SNE] Computed conditional probabilities for sample 159000 / 211950
# [t-SNE] Computed conditional probabilities for sample 160000 / 211950
# [t-SNE] Computed conditional probabilities for sample 161000 / 211950
# [t-SNE] Computed conditional probabilities for sample 162000 / 211950
# [t-SNE] Computed conditional probabilities for sample 163000 / 211950
# [t-SNE] Computed conditional probabilities for sample 164000 / 211950
# [t-SNE] Computed conditional probabilities for sample 165000 / 211950
# [t-SNE] Computed conditional probabilities for sample 166000 / 211950
# [t-SNE] Computed conditional probabilities for sample 167000 / 211950
# [t-SNE] Computed conditional probabilities for sample 168000 / 211950
# [t-SNE] Computed conditional probabilities for sample 169000 / 211950
# [t-SNE] Computed conditional probabilities for sample 170000 / 211950
# [t-SNE] Computed conditional probabilities for sample 171000 / 211950
# [t-SNE] Computed conditional probabilities for sample 172000 / 211950
# [t-SNE] Computed conditional probabilities for sample 173000 / 211950
# [t-SNE] Computed conditional probabilities for sample 174000 / 211950
# [t-SNE] Computed conditional probabilities for sample 175000 / 211950
# [t-SNE] Computed conditional probabilities for sample 176000 / 211950
# [t-SNE] Computed conditional probabilities for sample 177000 / 211950
# [t-SNE] Computed conditional probabilities for sample 178000 / 211950
# [t-SNE] Computed conditional probabilities for sample 179000 / 211950
# [t-SNE] Computed conditional probabilities for sample 180000 / 211950
# [t-SNE] Computed conditional probabilities for sample 181000 / 211950
# [t-SNE] Computed conditional probabilities for sample 182000 / 211950
# [t-SNE] Computed conditional probabilities for sample 183000 / 211950
# [t-SNE] Computed conditional probabilities for sample 184000 / 211950
# [t-SNE] Computed conditional probabilities for sample 185000 / 211950
# [t-SNE] Computed conditional probabilities for sample 186000 / 211950
# [t-SNE] Computed conditional probabilities for sample 187000 / 211950
# [t-SNE] Computed conditional probabilities for sample 188000 / 211950
# [t-SNE] Computed conditional probabilities for sample 189000 / 211950
# [t-SNE] Computed conditional probabilities for sample 190000 / 211950
# [t-SNE] Computed conditional probabilities for sample 191000 / 211950
# [t-SNE] Computed conditional probabilities for sample 192000 / 211950
# [t-SNE] Computed conditional probabilities for sample 193000 / 211950
# [t-SNE] Computed conditional probabilities for sample 194000 / 211950
# [t-SNE] Computed conditional probabilities for sample 195000 / 211950
# [t-SNE] Computed conditional probabilities for sample 196000 / 211950
# [t-SNE] Computed conditional probabilities for sample 197000 / 211950
# [t-SNE] Computed conditional probabilities for sample 198000 / 211950
# [t-SNE] Computed conditional probabilities for sample 199000 / 211950
# [t-SNE] Computed conditional probabilities for sample 200000 / 211950
# [t-SNE] Computed conditional probabilities for sample 201000 / 211950
# [t-SNE] Computed conditional probabilities for sample 202000 / 211950
# [t-SNE] Computed conditional probabilities for sample 203000 / 211950
# [t-SNE] Computed conditional probabilities for sample 204000 / 211950
# [t-SNE] Computed conditional probabilities for sample 205000 / 211950
# [t-SNE] Computed conditional probabilities for sample 206000 / 211950
# [t-SNE] Computed conditional probabilities for sample 207000 / 211950
# [t-SNE] Computed conditional probabilities for sample 208000 / 211950
# [t-SNE] Computed conditional probabilities for sample 209000 / 211950
# [t-SNE] Computed conditional probabilities for sample 210000 / 211950
# [t-SNE] Computed conditional probabilities for sample 211000 / 211950
# [t-SNE] Computed conditional probabilities for sample 211950 / 211950
# [t-SNE] Mean sigma: 0.000000
# /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 98.922264
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [63], in <cell line: 22>()
#      20 # tSNE Dimension Reduction
#      21 tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
# ---> 22 tsne_lda = tsne_model.fit_transform(arr)
#      24 # Plot the Topic Clusters using Bokeh
#      25 output_notebook()
#
# File ~/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:1123, in TSNE.fit_transform(self, X, y)
#    1103 """Fit X into an embedded space and return that transformed output.
#    1104
#    1105 Parameters
#    (...)
#    1120     Embedding of the training data in low-dimensional space.
#    1121 """
#    1122 self._check_params_vs_input(X)
# -> 1123 embedding = self._fit(X)
#    1124 self.embedding_ = embedding
#    1125 return self.embedding_
#
# File ~/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:1018, in TSNE._fit(self, X, skip_num_points)
#    1012 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1013 # degrees_of_freedom = n_components - 1 comes from
#    1014 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1015 # Laurens van der Maaten, 2009.
#    1016 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1018 return self._tsne(
#    1019     P,
#    1020     degrees_of_freedom,
#    1021     n_samples,
#    1022     X_embedded=X_embedded,
#    1023     neighbors=neighbors_nn,
#    1024     skip_num_points=skip_num_points,
#    1025 )
#
# File ~/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:1086, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1084     opt_args["momentum"] = 0.8
#    1085     opt_args["n_iter_without_progress"] = self.n_iter_without_progress
# -> 1086     params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1088 # Save the final number of iterations
#    1089 self.n_iter_ = it
#
# File ~/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:398, in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     395 # only compute the error when needed
#     396 kwargs["compute_error"] = check_convergence or i == n_iter - 1
# --> 398 error, grad = objective(p, *args, **kwargs)
#     399 grad_norm = linalg.norm(grad)
#     401 inc = update * grad < 0.0
#
# File ~/Downloads/ENTER/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:275, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     272 X_embedded = params.reshape(n_samples, n_components)
#     274 val_P = P.data.astype(np.float32, copy=False)
# --> 275 neighbors = P.indices.astype(np.int64, copy=False)
#     276 indptr = P.indptr.astype(np.int64, copy=False)
#     278 grad = np.zeros(X_embedded.shape, dtype=np.float32)
#
# KeyboardInterrupt:

# %%
# !pip3 install bokeh
# Out:
# Requirement already satisfied: bokeh in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (1.21.4)
# Requirement already satisfied: Jinja2>=2.9 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (8.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: pandas>=1.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (1.4.4)
# Requirement already satisfied: contourpy>=1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (1.0.6)
# Requirement already satisfied: tornado>=5.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (6.0)
# Requirement already satisfied: packaging>=16.8 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from bokeh) (21.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from packaging>=16.8->bokeh) (3.0.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pyLDAvis
from pyLDAvis import gensim

pyLDAvis.enable_notebook()
vis = gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# /Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 import pyLDAvis
# ----> 2 from pyLDAvis import gensim
#       4 pyLDAvis.enable_notebook()
#       5 vis = gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
#
# ImportError: cannot import name 'gensim' from 'pyLDAvis' (/Users/tavishipriyam/Downloads/ENTER/lib/python3.9/site-packages/pyLDAvis/__init__.py)

# %%
# !pip3 install pyLDAvis.gensim
